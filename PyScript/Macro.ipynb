# %%
import pyautogui
import time
import os

imgPath = os.path.join(os.getcwd(), 'ThemeImg')
if not os.path.exists(imgPath):
    os.mkdir(imgPath)

pyautogui.hotkey('ctrl', 'k', 't') # vscode theme 선택 단축키
time.sleep(0.3)
pyautogui.moveTo(800,90) # 맨 처음 테마 클릭 (노트북을 주 모니터로 사용할 시)
pyautogui.click()
time.sleep(0.3)
themeImg = pyautogui.screenshot(os.path.join(imgPath, 'test.png')) # 최종적으로 생성시 region 지정 필요 (pillow 객체 반환)
# pyautogui.screenshot(os.path.join(imgPath, 'test.png'), region=(0,0,0,0))

# 해당 구문 부터 반복문 작성
# pyautogui.hotkey('ctrl', 'k', 't')
# time.sleep(0.3)
# pyautogui.press('down')
# pyautogui.press('enter')
# time.sleep(0.3)
# pyautogui.screenshot(os.path.join(imgPath, 'test2.png'))

# 반복문,
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x25421871BE0>

# %%
themeImg.crop((290,100,1000,500))
# Out:
# <PIL.Image.Image image mode=RGB size=710x400 at 0x25420625C70>
