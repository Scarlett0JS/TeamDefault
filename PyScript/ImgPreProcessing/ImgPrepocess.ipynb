# %%
from PIL import Image
# from tqdm import tqdm
import os

img = Image.open("../macro/ThemeImg/test1_Python_JetBrains Mono.png")

# needs = ["ShowingTheme", "ProcessedImg"]
# for folder in needs:
#     dest = os.path.join(os.getcwd(), folder)
#     if not os.path.exists(dest):
#         os.mkdir(dest)


# for imgName in os.listdir("../macro/ThemeImg"):
#     img = Image.open(f"./ThemeImg/{imgName}")
#     cropImg = img.crop((0,74,1790,1030))
#     cropImg.save(f"./ThemeImg/{imgName}")
#     print(imgName)

# # img = Image.open('./ThemeImg/test1_Python_JetBrains Mono.png')
# # print(img.size)
# # img.crop((0,74,1790,1030))
# Out:
# <PIL.Image.Image image mode=RGB size=500x426>
