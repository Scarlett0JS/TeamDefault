# %%
import json

with open("reFinal_ThemeInfoImgCrawlextract.json", 'r', encoding="utf-8") as f:
    data = json.load(f)

sorted(set([(i['name'], i['InstallCnt'], i['imgpath'].split(".")[0].split("_")[2]) for i in data]), key=lambda x:x[1], reverse=True)
# Out:
# [('Light Visual Studio  CC ', 9436421, 'Python'),
#  ('Light Visual Studio  CC ', 9436421, 'Python'),
#  ('Light Visual Studio  CC ', 9436421, 'Python'),
#  ('Light Visual Studio  CC ', 9436421, 'Python'),
#  ('Light Visual Studio  CC ', 9436421, 'Python'),
#  ('Light Visual Studio  CC ', 9436421, 'Java'),
#  ('Light Visual Studio  CC ', 9436421, 'Java'),
#  ('Light Visual Studio  CC ', 9436421, 'Java'),
#  ('Light Visual Studio  CC ', 9436421, 'Java'),
#  ('Light Visual Studio  CC ', 9436421, 'Java'),
#  ('Light Visual Studio  CC ', 9436421, 'HTML'),
#  ('Light Visual Studio  CC ', 9436421, 'HTML'),
#  ('Light Visual Studio  CC ', 9436421, 'HTML'),
#  ('Light Visual Studio  CC ', 9436421, 'HTML'),
#  ('Light Visual Studio  CC ', 9436421, 'HTML'),
#  ('Light Visual Studio  CC ', 9436421, 'JavaScript'),
#  ('Light Visual Studio  CC ', 9436421, 'JavaScript'),
#  ('Light Visual Studio  CC ', 9436421, 'JavaScript'),
#  ('Light Visual Studio  CC ', 9436421, 'JavaScript'),
# ...
